# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
matplotlib.style.use('ggplot')

# %%
np.random.seed(1)
df = pd.DataFrame({
    'x1': np.random.normal(0, 2, 10000),
    'x2': np.random.normal(5, 3, 10000),
    'x3': np.random.normal(-5, 5, 10000)
})

# %%
min_max = preprocessing.minmax_scale(df)
scaler = preprocessing.StandardScaler()
scaled_df = scaler.fit_transform(df)

# %%
scaled_df = pd.DataFrame(scaled_df, columns=['x1', 'x2', 'x3'])

# %%
scaled_df
# Out:
#             x1        x2        x3
# 0     1.616535 -0.131753 -1.924757
# 1    -0.622285  0.218475 -0.146416
# 2    -0.538598 -0.361311 -0.820942
# 3    -1.084057 -0.838991 -0.192287
# 4     0.856675 -0.270204  1.045092
# ...        ...       ...       ...
# 9995  0.063263 -0.951512  0.707293
# 9996  0.479912  0.771862  0.569731
# 9997 -1.025161  2.396149 -0.069516
# 9998 -0.072557  0.872313 -1.274092
# 9999 -1.449402 -0.108902  0.358368
#
# [10000 rows x 3 columns]

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2,figsize = (20,6))
ax1.set_title("before scaling")
sns.kdeplot(data = df['x1'],ax=ax1)
sns.kdeplot(data = df['x2'], ax= ax1)
sns.kdeplot(data = df['x3'], ax=ax1)
ax2.set_title('after scaling')
sns.kdeplot(data= scaled_df['x1'],ax=ax2)
sns.kdeplot(data = scaled_df['x2'], ax=ax2)
sns.kdeplot(data=scaled_df['x3'], ax=ax2)
plt.show()

# %%
min_max_df = pd.DataFrame(data = min_max, columns=['x1','x2','x3'])

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2,figsize = (20,6))
ax1.set_title("before scaling")
sns.kdeplot(data = df['x1'],ax=ax1)
sns.kdeplot(data = df['x2'], ax= ax1)
sns.kdeplot(data = df['x3'], ax=ax1)
ax2.set_title('after scaling')
sns.kdeplot(data= min_max_df['x1'],ax=ax2)
sns.kdeplot(data = min_max_df['x2'], ax=ax2)
sns.kdeplot(data= min_max_df['x3'], ax=ax2)
plt.show()
